# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import norm

# %%
# Read the dataset to python environment.


a=pd.read_csv('StudentsPerformance.csv')
print(a.to_string())

print(a.shape)
# Out:
#      gender race/ethnicity parental level of education         lunch test preparation course  math score  reading score  writing score
# 0    female        group C            some high school  free/reduced                    none           0             17             10
# 1    female        group B                 high school  free/reduced                    none           8             24             23
# 2    female        group B            some high school  free/reduced                    none          18             32             28
# 3    female        group B                some college      standard                    none          11             38             32
# 4    female        group C                some college  free/reduced                    none          22             39             33
# 5    female        group B                 high school  free/reduced               completed          23             44             36
# ...

# %%
# Out:
# 5.0

# %%
#1. Find out how many males and females participated in the test.


import pandas as pd
a=pd.read_csv('StudentsPerformance.csv')

a.head()
female = 0
male = 0
for row in a:
    if a['gender'].any()=='female':
       female = female+1             
    else:
       male = male+1
    
    
    
print(a['gender'].tolist().count('female'))
print(a['gender'].tolist().count('male'))
# Out:
# 518
# 482

# %%
a['gender'].value_counts(normalize = True)
a['gender'].value_counts(dropna = False).plot.bar(color = 'magenta')
plt.title('Comparison of Males and Females')
plt.xlabel('gender')
plt.ylabel('count')
plt.show()
     

a.gender.value_counts()
# Out:
# female    518
# male      482
# Name: gender, dtype: int64

# %%
#2. What do you think about the students' parental level of education?
a['parental level of education'].value_counts(normalize = True)
a['parental level of education'].value_counts(dropna = False).plot.bar()
plt.title('Comparison of Parental Education')
plt.xlabel('Degree')
plt.ylabel('count')
plt.show()
a['parental level of education'].value_counts()
# Out:
# some college          226
# associate's degree    222
# high school           196
# some high school      179
# bachelor's degree     118
# master's degree        59
# Name: parental level of education, dtype: int64

# %%
3#. Who scores the most on average for math, reading and writing based on Gender and Test preparation course
 
print("Average math score is    : {}".format(np.mean(a['math score'])))
print("Average reading score is : {}".format(np.mean(a['reading score'])))
print("Average writing score is : {}".format(np.mean(a['writing score'])))
# Out:
# Average math score is    : 66.001
# Average reading score is : 69.195
# Average writing score is : 68.119

# %%
plt.rcParams['figure.facecolor'] = "#e6ecff"
plt.rcParams['axes.facecolor'] = "#e6ecff"
plt.figure(figsize=(14,8))
plt.subplot(1, 3, 1)
sns.barplot(x='test preparation course',y='math score',data=a,hue='gender',palette='seismic',**{'hatch':'*','alpha':0.6,'linewidth':2})
plt.title('MATH SCORES')
plt.subplot(1, 3, 2)
sns.barplot(x='test preparation course',y='reading score',data=a,hue='gender',palette='seismic',**{'hatch':'.','alpha':0.8,'linewidth':2})
plt.title('READING SCORES')
plt.subplot(1, 3, 3)
sns.barplot(x='test preparation course',y='writing score',data=a,hue='gender',palette='seismic',**{'hatch':'x','linewidth':2})
plt.title('WRITING SCORES')
plt.show()

plt.figure(figsize=(15,5))
plt.subplots_adjust(left=0.125, bottom=0.1, right=0.9, top=0.9,
                      wspace=0.5, hspace=0.2)
plt.subplot(131)
plt.title('Math Scores')
sns.barplot(x="gender", y="math score", data=a)
plt.subplot(132)
plt.title('Reading Scores')
sns.barplot(x="gender", y="reading score", data=a)
plt.subplot(133)
plt.title('Writing Scores')
sns.barplot(x="gender", y="writing score", data=a)
plt.show()

# %%
#  In maths girls are backward,but in reading and writing they scored

# %%
4.# What do you think about the scoring variation for math, reading and writing based on Gender and  Test preparation course


print("variance of math score is    : {}".format(np.var(a['math score'])))
print("variance of reading score is : {}".format(np.var(a['reading score'])))
print("variance of writing score is : {}".format(np.var(a['writing score'])))
# Out:
# variance of math score is    : 242.1689989999999
# variance of reading score is : 216.0629749999998
# variance of writing score is : 231.6108389999999

# %%
variation=a.groupby(['gender','test preparation course'])[['math score','reading score','writing score']].var()
print(variation)
# Out:
#                                 math score  reading score  writing score
# gender test preparation course
# female completed                208.173913     161.175546     149.836897
#        none                     272.602767     214.241220     225.495172
# male   completed                197.098133     185.297987     166.098233
#        none                     205.513600     184.843553     181.394687

# %%
5# The management needs your help to give bonus points to the top 25% ofstudents based on their math score, so how will you help the management
# to achieve this.



a["math score"].quantile(0.75) 
top25=a[a["math score"]>=77].sort_values("math score",ascending=False)
top25
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 999    male        group E           bachelor's degree      standard
# 998    male        group E          associate's degree  free/reduced
# 997    male        group D                some college      standard
# 996    male        group A                some college      standard
# 517  female        group E          associate's degree      standard
# ..      ...            ...                         ...           ...
# 854    male        group D            some high school      standard
# 855    male        group E          associate's degree  free/reduced
# 856    male        group E            some high school      standard
# 415  female        group B             master's degree  free/reduced
# 414  female        group A                 high school  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...
